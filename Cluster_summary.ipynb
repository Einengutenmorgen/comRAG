# %% [markdown]
# #Import

# %%
import pandas as pd 
import numpy as np

import tiktoken


from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

# %% [markdown]
# # load and transform

# %%
path= '/Users/mogen/AdvancedRag/Clustered_nomic/only_summaries_for_cluster.csv'
df= pd.read_csv(path)

# %%
df.head()
# Out:
#                                              summary  \
# 0   Pantites is a Spartan who survived the Battle...
# 1   Panorama, an Italian magazine, is known for i...
# 2   Santa Claus is commonly depicted as a jolly, ...
# 3   Marilyn Monroe, a prominent figure in America...
# 4   Kongjwi is the protagonist of a Korean folkta...
#
#                                   entity_description  \
# 0  ['Another one of the few Spartans who survived...
# 1  ["Italian magazine that ran an article claimin...
# 2  ['Common image of Santa Claus as a jolly large...
# 3  ['Prominent figure whose death attracted consp...
# 4  ['Kongjwi is the protagonist of the Korean fol...
#
#                                             chunk_id          entity  \
# 0  ['9f93a327-a1aa-4e54-9423-36eb4f551ff4', 'c07c...        PANTITES
# 1  ['3e52c447-8951-463b-892d-af5fa00ee0ba', 'f3f4...        PANORAMA
# 2  ['37b36ae6-1867-4277-ad86-8bc6924c8ae7', 'c372...     SANTA CLAUS
# 3  ['51aff810-0628-4137-a9a5-83767e76cad8', '6f2b...  MARILYN MONROE
# 4  ['f50bd7cf-b983-49a0-aa9e-cedb62fe3caa', 'bbd0...         KONGJWI
#
#   Nomic Topic: medium        Nomic Topic: broad   entity_type  \
# 0        Ancient Wars         Miscellaneous (7)        PERSON
# 1          Journalism  Classic Animated Stories  ORGANIZATION
# 2             Royalty  Classic Animated Stories        PERSON
# 3   Ancient Egyptians      Supernatural Beliefs        PERSON
# 4         Stepsisters  Classic Animated Stories        PERSON
#
#                                               doc_id  row_number
# 0           ['85815899-ca08-40eb-808d-22b703f69c2c']       11963
# 1  ['46b13c0c-2951-4371-98a7-18dc98a577d2', '93e4...        1663
# 2  ['472b5fc4-d5dd-4ffe-b763-09f155980143', '5bef...         498
# 3           ['46b13c0c-2951-4371-98a7-18dc98a577d2']        1529
# 4           ['a2066840-c5c9-4817-b5bd-96eb0cf42c1b']        3392

# %%
# Grouping by 'Nomic Topic: medium' and 'Nomic Topic: broad', and getting distribution
medium_distribution = df['Nomic Topic: medium'].value_counts()
broad_distribution = df['Nomic Topic: broad'].value_counts()


medium_distribution
# Out:
# Nomic Topic: medium
# Chemistry Nobel Prize    188
# Music                    181
# Physics                  175
# Miscellaneous (4)        164
# Misconception            157
#                         ...
# Homophobia                 5
# City Council Meeting       5
# Laws                       4
# Cartoon Similarities       4
# Butter                     4
# Name: count, Length: 256, dtype: int64

# %%
broad_distribution
# Out:
# Nomic Topic: broad
# Behavioral Health              3721
# Miscellaneous (7)              3089
# Classic Animated Stories       2046
# Nobel Prize                    1761
# Supernatural Beliefs           1085
# Mexican Cuisine                 604
# Artificial Intelligence (3)     565
# Languages (2)                   559
# Name: count, dtype: int64

# %%
# Grouping summaries by 'Nomic Topic: medium'
summaries_by_medium = df.groupby('Nomic Topic: medium')['summary'].apply(list)

# Grouping summaries by 'Nomic Topic: broad'
summaries_by_broad = df.groupby('Nomic Topic: broad')['summary'].apply(list)

# %%
summaries_by_medium
# Out:
# Nomic Topic: medium
# Actor                   [ The French Legion of Honor, a prestigious or...
# Africa                  [ Africa, a continent located in the Eastern H...
# Airlines                [ Heathrow Airport serves as the main hub for ...
# Airport                 [ Athens International Airport, located in the...
# Aladdin                 [ Roulbadour is a princess, known as the Sulta...
#                                               ...
# Vampires (2)            [ SIANGUISTIC VAMPIRISM is a contemporary subc...
# Vietnamese Pop Music    [ Pop music is a genre of music that is legall...
# War                     [ The Gadsden Purchase refers to the acquisiti...
# Water                   [ Milk is a liquid that is frequently mentione...
# Weather                 [ The time period of 18301831 UTC marks an ins...
# Name: summary, Length: 256, dtype: object

# %%
type(summaries_by_medium)
# Out:
# pandas.core.series.Series

# %%
# Grouping the medium topics within each broad topic and getting the distribution
medium_in_broad = df.groupby('Nomic Topic: broad')['Nomic Topic: medium'].apply(list)

# Showing the distribution of medium topics within each broad category
medium_in_broad_distribution = medium_in_broad.apply(lambda x: pd.Series(x).value_counts())
medium_in_broad_distribution
# Out:
#                              Polygraph Tests  Artificial Intelligence  \
# Nomic Topic: broad
# Artificial Intelligence (3)             78.0                     70.0
# Behavioral Health                        NaN                      NaN
# Classic Animated Stories                 NaN                      NaN
# Languages (2)                            NaN                      NaN
# Mexican Cuisine                          NaN                      NaN
# Miscellaneous (7)                        NaN                      NaN
# Nobel Prize                              NaN                      NaN
# Supernatural Beliefs                     NaN                      NaN
#
#                              Psychopathy Assessment Tool  Telepathy  \
# Nomic Topic: broad
# Artificial Intelligence (3)                         69.0       60.0
# Behavioral Health                                    NaN        NaN
# Classic Animated Stories                             NaN        NaN
# Languages (2)                                        NaN        NaN
# Mexican Cuisine                                      NaN        NaN
# Miscellaneous (7)                                    NaN        NaN
# Nobel Prize                                          NaN        NaN
# Supernatural Beliefs                                 NaN        NaN
#
#                              Miscellaneous  Scientific Publications  \
# Nomic Topic: broad
# Artificial Intelligence (3)           58.0                     54.0
# Behavioral Health                      NaN                      NaN
# Classic Animated Stories               NaN                      NaN
# Languages (2)                          NaN                      NaN
# Mexican Cuisine                        NaN                      NaN
# Miscellaneous (7)                      NaN                      NaN
# Nobel Prize                            NaN                      NaN
# Supernatural Beliefs                   NaN                      NaN
#
#                              Artificial Intelligence (2)  \
# Nomic Topic: broad
# Artificial Intelligence (3)                         53.0
# Behavioral Health                                    NaN
# Classic Animated Stories                             NaN
# Languages (2)                                        NaN
# Mexican Cuisine                                      NaN
# Miscellaneous (7)                                    NaN
# Nobel Prize                                          NaN
# Supernatural Beliefs                                 NaN
#
#                              Ganzfeld Experiments  Psychic Experiments  \
# Nomic Topic: broad
# Artificial Intelligence (3)                  31.0                 27.0
# Behavioral Health                             NaN                  NaN
# Classic Animated Stories                      NaN                  NaN
# Languages (2)                                 NaN                  NaN
# Mexican Cuisine                               NaN                  NaN
# Miscellaneous (7)                             NaN                  NaN
# Nobel Prize                                   NaN                  NaN
# Supernatural Beliefs                          NaN                  NaN
#
#                              Medicine  ...  Hinduism  \
# Nomic Topic: broad                     ...
# Artificial Intelligence (3)      23.0  ...       NaN
# Behavioral Health                 NaN  ...       NaN
# Classic Animated Stories          NaN  ...       NaN
# Languages (2)                     NaN  ...       NaN
# Mexican Cuisine                   NaN  ...       NaN
# Miscellaneous (7)                 NaN  ...       NaN
# Nobel Prize                       NaN  ...       NaN
# Supernatural Beliefs              NaN  ...      32.0
#
#                              DNA, mtDNA, Mitochondria, Evolutionary  \
# Nomic Topic: broad
# Artificial Intelligence (3)                                     NaN
# Behavioral Health                                               NaN
# Classic Animated Stories                                        NaN
# Languages (2)                                                   NaN
# Mexican Cuisine                                                 NaN
# Miscellaneous (7)                                               NaN
# Nobel Prize                                                     NaN
# Supernatural Beliefs                                           32.0
#
#                              Balancing  Carpets/Textiles  Sushi  \
# Nomic Topic: broad
# Artificial Intelligence (3)        NaN               NaN    NaN
# Behavioral Health                  NaN               NaN    NaN
# Classic Animated Stories           NaN               NaN    NaN
# Languages (2)                      NaN               NaN    NaN
# Mexican Cuisine                    NaN               NaN    NaN
# Miscellaneous (7)                  NaN               NaN    NaN
# Nobel Prize                        NaN               NaN    NaN
# Supernatural Beliefs              21.0              20.0   20.0
#
#                              Mythical Creatures  Ayurveda  Economic Crisis  \
# Nomic Topic: broad
# Artificial Intelligence (3)                 NaN       NaN              NaN
# Behavioral Health                           NaN       NaN              NaN
# Classic Animated Stories                    NaN       NaN              NaN
# Languages (2)                               NaN       NaN              NaN
# Mexican Cuisine                             NaN       NaN              NaN
# Miscellaneous (7)                           NaN       NaN              NaN
# Nobel Prize                                 NaN       NaN              NaN
# Supernatural Beliefs                       15.0      13.0              9.0
#
#                              Spyglass  Butter
# Nomic Topic: broad
# Artificial Intelligence (3)       NaN     NaN
# Behavioral Health                 NaN     NaN
# Classic Animated Stories          NaN     NaN
# Languages (2)                     NaN     NaN
# Mexican Cuisine                   NaN     NaN
# Miscellaneous (7)                 NaN     NaN
# Nobel Prize                       NaN     NaN
# Supernatural Beliefs              6.0     4.0
#
# [8 rows x 256 columns]

# %%
def get_non_nan_columns(row):
    return ", ".join(medium_in_broad_distribution.columns[~row.isna()])

# Applying the function to get non-NaN columns for each row
non_nan_columns_per_row = medium_in_broad_distribution.apply(get_non_nan_columns, axis=1)
df_inspect=pd.DataFrame(non_nan_columns_per_row)
df_inspect.to_csv('/Users/mogen/AdvancedRag/Clustered_nomic/df_inspect.csv')

# %%
nan_count_per_row = medium_in_broad_distribution.isna().sum(axis=1)
nan_count_per_row
# Out:
# Nomic Topic: broad
# Artificial Intelligence (3)    243
# Behavioral Health              179
# Classic Animated Stories       215
# Languages (2)                  247
# Mexican Cuisine                242
# Miscellaneous (7)              199
# Nobel Prize                    237
# Supernatural Beliefs           230
# dtype: int64

# %% [markdown]
# #Summarize

# %% [markdown]
# #### Prompt

# %%
prompt_medium= '''You are an expert summarizer tasked with analyzing a set of entity descriptions. Your goal is to generate a comprehensive and detailed summary for the entity "{Entity}" based on the following descriptions. Each description is derived from different source texts and may contain varying perspectives and details.

- Carefully merge the information from all the provided descriptions into a single cohesive summary.
- Preserve as much relevant detail as possible from each description.
- Identify and clearly state any implicit knowledge or insights that may not be explicitly mentioned but can be inferred from the context.
- Ensure that the summary is clear, factual, and focuses on the key attributes, behaviors, relationships, and characteristics of the entity.

Entity Descriptions
{Description}

Example:

{{
  "entity_name": "[ENTITY_NAME]",
  "detailed_summary": "[Generated detailed summary merging explicit and implicit details]"
}}

---
Output:

'''

# %%
#data 
df_sumamries_p_label= pd.DataFrame(summaries_by_medium)
df_reset = df_sumamries_p_label.reset_index()
df_reset.columns = ['Nomic Topic: medium', 'summary']
# Remove the header row
df_reset
# Out:
#       Nomic Topic: medium                                            summary
# 0                   Actor  [ The French Legion of Honor, a prestigious or...
# 1                  Africa  [ Africa, a continent located in the Eastern H...
# 2                Airlines  [ Heathrow Airport serves as the main hub for ...
# 3                 Airport  [ Athens International Airport, located in the...
# 4                 Aladdin  [ Roulbadour is a princess, known as the Sulta...
# ..                    ...                                                ...
# 251          Vampires (2)  [ SIANGUISTIC VAMPIRISM is a contemporary subc...
# 252  Vietnamese Pop Music  [ Pop music is a genre of music that is legall...
# 253                   War  [ The Gadsden Purchase refers to the acquisiti...
# 254                 Water  [ Milk is a liquid that is frequently mentione...
# 255               Weather  [ The time period of 18301831 UTC marks an ins...
#
# [256 rows x 2 columns]

# %%
# Format the prompt with the entity name and descriptions
entity_names=df_reset['Nomic Topic: medium'].tolist()
descriptions_l=df_reset['summary'].tolist()
formatted_prompt_list=[]
prompt_lengths=[]
# Format the prompt with the entity name and descriptions
for entity_name, descriptions in zip(entity_names, descriptions_l):
    formatted_prompt = prompt_medium.format(Entity=entity_name, Description=descriptions)
    prompt_length = len(formatted_prompt)
    prompt_lengths.append(prompt_length)
    formatted_prompt_list.append(formatted_prompt)

max_length = max(prompt_lengths)
avg_length = np.mean(prompt_lengths)
median_length = np.median(prompt_lengths)

# Displaying the results
print(f'{len(formatted_prompt_list)} entries created and append to list')
print(f'max_length: {max_length} ')
print(f'avg_length: {avg_length} ')
print(f'median_length: {median_length} ')
# Out:
# 256 entries created and append to list
# max_length: 61477
# avg_length: 19320.66796875
# median_length: 17487.0

# %%
# Initialize the tokenizer (e.g., for GPT-3.5, use 'gpt-3.5-turbo')
encoding = tiktoken.get_encoding("cl100k_base")
# List to store the token count for each prompt
token_counts = []
entity_names__= []
# Estimate token count for each formatted prompt
for entity_name, descriptions in zip(entity_names, descriptions_l):
    formatted_prompt = prompt_medium.format(Entity=entity_name, Description=descriptions)
    
    # Encode the prompt to estimate the token number
    token_count = len(encoding.encode(formatted_prompt))
    if token_count>6000:
        token_counts.append(token_count)    
        entity_names__.append(entity_name)


# Display the token counts
for e, t in zip(entity_names__, token_counts):
    print(e, t)
# Out:
# Airlines 9335
# Ancient Wars 8650
# Arabic Dialects 6535
# Arabic Scholars 6157
# Autobahn 7553
# Carpets, Floors, Coverings 7895
# Chemistry Nobel Prize 10706
# Cinderella Film 7336
# Coastal City 8193
# Conspiracy Theories 7045
# Crime Documentation 6369
# Energy 7259
# European Countries 6803
# European Union 7007
# Evolutionary Biology 6466
# Flight Incident 6295
# Flight incident 7006
# Legal Proceedings 8835
# Literature 6927
# Literature (2) 9101
# Medicine (3) 10698
# Medicine, Physiology, Nobel Prize 9533
# Medieval History 6022
# Mental Disorders 6995
# Miscellaneous (4) 13614
# Misconception 11085
# Missionaries 6504
# Music 11707
# Niger Delta Conflict 7603
# Peace, rights, diplomacy, Ghana 6902
# Physics 11509
# Political Outburst 7404
# Psychopathy Assessment Tool 6449
# Robotics Laws (2) 6739
# SARS 6247
# Terrorist Attacks 8532
# Vampire folklore 6676

# %% [markdown]
# # High level community Prompt

# %%
community_summaries.columns
# Out:
# Index(['index', '0',
#        '{\n  "entity_name": "Actor",\n  "detailed_summary": "Tom Hanks, an American actor, producer, and filmmaker, is a renowned figure in the film industry. Born in California, Hanks has roots in the Roman Empire as his ancestors emigrated to the United States in the 18th century, settling in Kentucky and changing their last name to Mefford. He is also a distant relative of the 16th US president, Abraham Lincoln. Hanks gained fame for his roles in films such as Forrest Gump, Saving Private Ryan, and Cast Away. He has won multiple Academy Awards, including two consecutive Best Actor awards for Philadelphia (1993) and Forrest Gump (1994). Hanks also received a Tony Award nomination for Best Actor in a Play for his performance in Nora Ephron's play Lucky Guy in 2013.\n\nIn addition to acting, Hanks has produced movies such as My Big Fat Greek Wedding (2002) and received the American Film Institute's Life Achievement Award in 2002. He appeared in three films in 2004: The Ladykillers, The Terminal, and The Polar Express. Hanks is also a vice president of the Academy of Motion Picture Arts and Sciences.\n\nHanks has been involved in various activities such as collecting manual typewriters, creating an iOS app called Hanx Writer, donating blood antibodies for virus research, officiating a wedding, founding Hanx for the Troops coffee company, writing short stories and novels. He voiced Sheriff Woody in the Toy Story films (1995–2019) and directed comedies That Thing You Do! (1996) and Larry Crowne (2011). In 1998, he launched his production company Playtone.\n\nHanks has also worked with directors such as Ron Howard, Nora Ephron, and Robert Zemeckis. Some of the films he has acted in include Bridge of Spies (2015), The Post (2017), Band of Brothers (2001), Sleepless in Seattle (1993), Apollo 13 (1995), and Cloud Atlas (2012). He has also directed the comedies That Thing You Do! (1996) and Larry Crowne (2011).\n\nIn recent years, Hanks has played roles in Captain Phillips (2013), A Hologram for the King (2016), Sully (2016), Inferno (2016), The Circle (2017), The David S. Pumpkins Halloween Special, Toy Story 4 (2019), and A Beautiful Day in the Neighborhood (2019). He also played airline captain Chesley Sullenberger.\n\nHanks is also known for his philanthropy, including donations to various charities and causes. He has been involved in disaster relief efforts, such as raising funds for victims of Hurricane Katrina and the Japanese tsunami. He has also supported organizations that focus on education, healthcare, and environmental conservation.\n\nThroughout his career, Hanks has received numerous accolades, including the French Legion of Honor, the Golden Globe Cecil B. DeMille Award, the Kennedy Center Honors Medallion, and the Douglas S Morrow Public Outreach Award. He has also been recognized for his work in television, winning 7 Primetime Emmy Awards for his work as a producer on various limited series and television films."\n}'],
#       dtype='object')

# %%
import json
from collections import defaultdict
path= '/Users/mogen/AdvancedRag/Clustered_nomic/community_summaries.csv'
community_summaries = pd.read_csv(path, header=None)
#community_summaries.reset_index(inplace=True)
# Assuming community_summaries is your dataframe and '0' is the column containing the data
raw_data = community_summaries[1].tolist()
parsed_cells=[]

# %%
for cell in raw_data:
    print(f"Original cell:\n{cell}")
    
    # Remove newline characters and make sure quotes are escaped properly
    cell_ = cell.replace('\n', '').replace('""', '"').replace('""', '"')
    
    try:
        # Try parsing the cleaned string using json.loads
        parsed_cell = json.loads(cell_)
        parsed_cells.append(parsed_cell)
    except json.JSONDecodeError as e:
        print(f"\nError parsing the cell: {e}")
        

def combine_dicts(dict_list):
    combined_dict = defaultdict(list)
    
    # Iterate through each dictionary in the list
    for d in dict_list:
        for key, value in d.items():
            combined_dict[key].append(value)
    
    return dict(combined_dict)


Dict_cs=combine_dicts(parsed_cells)
df_combined = pd.DataFrame(Dict_cs)
df_combined.to_csv('/Users/mogen/AdvancedRag/Clustered_nomic/_medium_level_community_summaries.csv')
# Out:
# Original cell:
# {
#   "entity_name": "Actor",
#   "detailed_summary": "Tom Hanks, an American actor, producer, and filmmaker, is a renowned figure in the film industry. Born in California, Hanks has roots in the Roman Empire as his ancestors emigrated to the United States in the 18th century, settling in Kentucky and changing their last name to Mefford. He is also a distant relative of the 16th US president, Abraham Lincoln. Hanks gained fame for his roles in films such as Forrest Gump, Saving Private Ryan, and Cast Away. He has won multiple Academy Awards, including two consecutive Best Actor awards for Philadelphia (1993) and Forrest Gump (1994). Hanks also received a Tony Award nomination for Best Actor in a Play for his performance in Nora Ephron's play Lucky Guy in 2013.\n\nIn addition to acting, Hanks has produced movies such as My Big Fat Greek Wedding (2002) and received the American Film Institute's Life Achievement Award in 2002. He appeared in three films in 2004: The Ladykillers, The Terminal, and The Polar Express. Hanks is also a vice president of the Academy of Motion Picture Arts and Sciences.\n\nHanks has been involved in various activities such as collecting manual typewriters, creating an iOS app called Hanx Writer, donating blood antibodies for virus research, officiating a wedding, founding Hanx for the Troops coffee company, writing short stories and novels. He voiced Sheriff Woody in the Toy Story films (1995–2019) and directed comedies That Thing You Do! (1996) and Larry Crowne (2011). In 1998, he launched his production company Playtone.\n\nHanks has also worked with directors such as Ron Howard, Nora Ephron, and Robert Zemeckis. Some of the films he has acted in include Bridge of Spies (2015), The Post (2017), Band of Brothers (2001), Sleepless in Seattle (1993), Apollo 13 (1995), and Cloud Atlas (2012). He has also directed the comedies That Thing You Do! (1996) and Larry Crowne (2011).\n\nIn recent years, Hanks has played roles in Captain Phillips (2013), A Hologram for the King (2016), Sully (2016), Inferno (2016), The Circle (2017), The David S. Pumpkins Halloween Special, Toy Story 4 (2019), and A Beautiful Day in the Neighborhood (2019). He also played airline captain Chesley Sullenberger.\n\nHanks is also known for his philanthropy, including donations to various charities and causes. He has been involved in disaster relief efforts, such as raising funds for victims of Hurricane Katrina and the Japanese tsunami. He has also supported organizations that focus on education, healthcare, and environmental conservation.\n\nThroughout his career, Hanks has received numerous accolades, including the French Legion of Honor, the Golden Globe Cecil B. DeMille Award, the Kennedy Center Honors Medallion, and the Douglas S Morrow Public Outreach Award. He has also been recognized for his work in television, winning 7 Primetime Emmy Awards for his work as a producer on various limited series and television films."
# }
# Original cell:
# {
#   "entity_name": "Africa",
#   "detailed_summary": "Africa, a vast continent located in the Eastern Hemisphere, is known for its rich cultural diversity and unique traditions. It is home to numerous countries, including Egypt, Morocco, Algeria, Tunisia, Mali, and many others. The continent is significant in healthcare, with traditional medicine being used for approximately 80% of primary healthcare. It is also a region where folktales featuring beings with vampiric abilities exist. Interestingly, the UK introduced LHT (Lymphatic Filariasis Transmission Assessment Survey) in various African countries. The continent's languages vary widely, with Arabic, Hassaniya, and local dialects being spoken. Notable cultural practices include the use of the Latin alphabet for writing Hassaniya and children throwing their baby teeth into chicken coops in Mali. Africa's railway systems, built using LHT British technology, remain LHT to this day. The continent's history is marked by ancient civilizations, such as Pharaonic Egypt, and significant events like The Exodus and the Israelites' enslavement. Central Africa is known for the origin of Zebola, a specific entity whose exact nature remains unspecified. The Eastern Nile Delta, a geographical region, is characterized by its fertile delta formed by the confluence of the Nile River's Rosetta, Damietta, and Bar-Lev branches, and is known for its rich agricultural land and ancient sites."
# }
# Original cell:
# {
#   "entity_name": "Airlines",
#   "detailed_summary": "Airlines, in this context, primarily refers to British Airways, a prominent British national flag carrier and one of the most profitable air carriers in the world. Established on 1 April 1972, it unified its branding on 31 March 1974 following the merger of BOAC, BEA, Cambrian Airways, and Northeast Airlines. The resulting airline corporation is a major airline in the United Kingdom that operates out of Heathrow Airport and Gatwick Airport, serving over 170 destinations in 70 countries. British Airways is known for its tiered loyalty programme called Executive Club and offers flights, lounges, and a buy on board system with food designed by Tom Kerridge. The airline operates a fleet of 253 aircraft, with 47 orders placed for future acquisitions. It has faced challenges such as a data breach in 2018, a computer power failure in 2017, and the temporary closure of Airway R-20 in 2020, which it resisted. British Airways has also been involved in subsidiaries and franchises, including Flybe and Eurostar, although it sold its stake in Flybe in 2014. Staff working for British Airways are represented by various trade unions, such as the British Air Line Pilots' Association and Unite the Union. British Airways has experienced significant events throughout its history, including the retirement of its entire 747-400 fleet in 2020, the incorporation of modern and fuel-efficient aircraft such as the Airbus A350 and Boeing 787, and plans to eliminate carbon emissions by 2050. The airline has been consistently ranked within the top 20 safest globally and is committed to providing safe air travel services."
# }
# Original cell:
# {
#   "entity_name": "Airport",
#   "detailed_summary": "Airports are significant transportation hubs located in various cities worldwide, including Athens, New York City, Mexico City, London, Anchorage, Copenhagen, GIMPO, and Seoul (Kimpo International Airport). These airports serve as departure and arrival points for numerous international and domestic flights, connecting cities and countries. Some airports, such as London Heathrow, serve as destinations for ferried planes. Others, like John F Kennedy International Airport in New York City, serve as departure points for specific airlines, such as Korean Air Lines. Airports also play crucial roles in historical events, such as the landing of the Concorde's first supersonic passenger service at Bahrain International Airport, and the emergency landing of a Boeing 747-200 at Halim Perdanakusuma International Airport. Some airports, like the Mexico City International Airport, handle a high volume of passengers, with approximately 45 million passengers annually. Airports also serve as refueling stops, as seen with Anchorage International Airport for Korean Air Lines Flight 007. The Tokyo Area Control Center is the primary air traffic control center for the region, managing and directing the movement of aircraft to ensure safe and efficient travel. The NOPAC North Pacific Routes are airways that span the coasts of Alaska and Japan, serving as crucial connections between these two regions. The airport system in Mexico consists of a total of 233 airports, all equipped with paved runways, facilitating air travel within the country and beyond."
# }
# Original cell:
# {
#   "entity_name": "Aladdin",
#   "detailed_summary": "Aladdin is a central character in various adaptations of the Arabian folktale, known for his heroic deeds. He is initially intended to marry Princess Pari Banou, a significant character from the animated silent film The Adventures of Prince Achmed, but his life takes a turn when he saves Princess Badroulbadour, the Sultan's daughter, from an unwanted marriage. In the more commonly known Disney version of the story, Badroulbadour becomes Aladdin's wife. Aladdin is assisted by characters such as Widow Twankey, a wise and humorous figure in British theatre pantomimes, and the Witch of the Fiery Mountain, who helps him and Prince Achmed in their joint efforts to defeat a powerful sorcerer. Aladdin's story shares similarities with other versions of the tale, such as the Cham version known as LA Sandele Dor."
# }
# Original cell:
# {
#   "entity_name": "Algebraic Structures and Ultraproducts",
#   "detailed_summary": "Algebraic structures is a broad term encompassing various mathematical systems such as groups, rings, fields, modules, vector spaces, and more. These structures are studied systematically in the field of Abstract Algebra, along with their relationships and transformations. Ultraproducts are a significant mathematical concept used to construct a single structure from a collection of structures, acting as a filter product space where elements are equal if they are equal only at the filtered components. This construction is primarily used in abstract algebra and mathematical logic. Ultraproducts can be constructed by taking the product of copies of a given structure and then applying an ultrafilter to select certain elements. They are essential in the creation of hyperreal numbers from copies of the real numbers for every natural number, with regard to an ultrafilter over the natural numbers containing all cofinite sets. Ultraproducts are also a tool in the study and manipulation of structures across various categories, offering a unified framework for understanding complex relationships between them. The Ultraproduct Monad is a mathematical tool that allows for the construction of certain types of limits, particularly ultralimits, within a category. Ultraproducts are constructed using ultrafilters, which are special types of filters that generalize the notion of a filter and are used to construct ultraproducts. Ultraproducts are significant in algebraic characterizations like Keisler's Ultrapower Theorem, which provides an algebraic interpretation of the semantic notion of elementary equivalence. It is worth noting that the term 'Algebraic Structures' also includes the concept of equivalence relations, which are binary relations that group elements into equivalence classes based on a common property or relationship. Equivalence classes ensure that the following three conditions are met: reflexivity, symmetry, and transitivity. The term 'Algebraic Structures' can also refer to the ULTRAFILTER, a maximal filter used to construct ultraproducts, and the ULTRAPOWER, a mathematical concept in set theory that extends certain properties of the original structure to larger collections using ultrafilters and the Axiom of Choice."
# }
# Original cell:
# {
#   "entity_name": "Algorithm",
#   "detailed_summary": "The term 'Algorithm' is not explicitly mentioned in the provided descriptions, but it can be inferred that the context refers to various processes, systems, or methods used to achieve specific goals or tasks. These can range from mathematical formulas, computer programs, decision-making procedures, or even historical events or processes.
#
# In the context of the entertainment industry, algorithms can be used for DVD release scheduling (November 6, 2007 and January 26, 2024), poll conduction (August 2016), and event scheduling (September 10, 2007, September 7, and September 1).
#
# In the realm of politics, algorithms can be used to determine penalties for tailgating (May 2006) and to schedule meetings (The Central Institution).
#
# In the field of research, algorithms can be used for conducting studies (April 2011, October 2009, and 2016), analyzing data (1906, 1969, and 2001), and making predictions (AlphaGo's matches in 2016).
#
# In the world of music, algorithms can be used for releasing music (While You Were Sleeping, The Doomsday EP, All the Night Without Love, and LONGLEGS' Zilgi).
#
# In the historical context, algorithms can be used to analyze communications (September 7) and to determine the direction and strategies of institutions (The Central Institution).
#
# In the context of social events, algorithms can be used for scheduling celebrations (Juneteenth, Christmas, and EPCOT's 39th anniversary) and for regulating public assemblies (April 2010's unruly gathering ordinance).
#
# In the context of legal proceedings, algorithms can be used for determining guilt or innocence (Sally Clark's case in 1998)."
# }
# Original cell:
# {
#   "entity_name": "Algorithmic Game Play",
#   "detailed_summary": "Algorithmic Game Play refers to the application of various algorithms in the context of games, particularly in the domain of Go. Notable examples include AlphaGeometry, which demonstrated high proficiency in solving geometry-related tasks, and the Sorting Algorithm developed by AlphaDev, which offers efficiency improvements of up to 70% for shorter sequences and 1.7% for longer sequences. Monte Carlo Tree Search (MCTS) is a common technique used in these algorithms, employed by systems like AlphaGo and DARKFOREST to evaluate positions and identify high-probability moves. This method is often combined with machine learning for enhanced decision-making. AlphaGo Master, a variant of AlphaGo, analyzed Go openings using 10,000,000 simulations, providing valuable insights into potential outcomes and optimal moves for each opening. The AlphaGo Teaching Tool, launched by DeepMind, serves as an educational resource, evaluating the winning rates of various Go openings as calculated by AlphaGo Master. Additionally, there are other algorithms like the Hashing Algorithm, developed by AlphaDev, which demonstrates a significant speed advantage in certain cases, being 30% faster compared to other algorithms under specific conditions. It's worth noting that these algorithms are not limited to Go; for instance, the TIYGEM SERVER hosts competitive gaming sessions between skilled individuals and a user known as 'Magister', while DARKFOREST is a system developed by Facebook for the game of Go. Lastly, Google Meet applies the video compression results of MuZero, a general-purpose reinforcement learning algorithm, to enhance the efficiency and quality of video conferencing on its platform."
# }
# Original cell:
# {
#   "entity_name": "Alternative Medicine",
#   "detailed_summary": "Alternative Medicine refers to a diverse range of practices, substances, and therapies that are used in lieu of or in conjunction with conventional medicine. These practices encompass a wide array of methods, including herbalism, crystal healing, aromatherapy, chiropractic, and various forms of body work such as massage and acupressure. Some examples of substances used in alternative medicine include Aloe Vera, Echinacea, Ginseng, and Shungite. It is important to note that while some of these practices and substances have been traditionally used for medicinal purposes, their effectiveness and safety are often controversial and not supported by strong scientific evidence. Additionally, the use of alternative medicine can potentially pose risks when combined with conventional treatments, as interactions with chemotherapy drugs, radiation therapy, or anesthetics during surgery may lead to dangerous outcomes. It is advisable for individuals considering alternative therapies to consult with healthcare professionals and discuss any potential risks or interactions before proceeding."
# }
# Original cell:
# {
#   "entity_name": "Ancestry",
#   "detailed_summary": "Ancestry refers to the lineage or descent of individuals, tracing back their genetic and genealogical connections. This concept is central to understanding human history, evolution, and migration patterns. Ancestry can be traced through various means, such as mitochondrial DNA (mtDNA) and Y-chromosomal DNA, which provide insights into patrilineal and matrilineal lineages, respectively. The Most Recent Common Ancestor (MRCA) is a significant entity in the study of ancestry, representing the last known common ancestor of a particular group of individuals. For example, the Y-MRCA is the last known male from whom all current living males are directly descended via the paternal line, while the Human MRCA is a hypothetical ancestor based on mtDNA, serving as a point of genetic connection for all contemporary human lineages. Notable ancestors include EVE, the most recent common matrilineal ancestor of all currently living human beings, and the mitochondrial Eve, who lived approximately 200,000 years ago in Africa. Ancestry also encompasses the study of more recent ancestors, such as the BIG PEOPLE, a group of humans who served under the Authority and were tasked with the mission to exterminate the Gallivespians, or the immigrants who arrived at Ellis Island. The study of ancestry provides valuable insights into human history, cultural diversity, and our shared genetic connections."
# }
# Original cell:
# {
#   "entity_name": "Ancient Egyptians",
#   "detailed_summary": "The Ancient Egyptians were a civilization known for their extensive mining activities, particularly for crystals. They utilized these minerals not only for creating intricate jewelry but also for metaphysical purposes. The Ancient Egyptians employed amulets, which often symbolized deities and their associated powers. These amulets served as tangible representations of the divine power and presence of the deity in daily life, offering protection and guidance to those who wore them. The Egyptians also believed in the use of crystals for healing and protection purposes. They buried their dead with various amulets, including the Lapis Lazuli Scarab, which was traditionally buried with the deceased in various Egyptian cultures. Its primary purpose was to offer protection and aid in the afterlife. The practice of burying a corpse upside down was also a cultural tradition aimed at preventing the recently deceased from transforming into an undead revenant. This ritual was believed to hinder any potential return of the deceased as a malevolent spirit, thus ensuring peace for both the living and the departed. The Ancient Egyptians also had funerary practices that involved placing the deceased in tombs adorned with various artifacts, including gold masks, jewelry, chariots, and other treasures. The tomb of the ancient Egyptian Pharaoh Tutankhamun, discovered in 1922, is a significant archaeological site that houses the remains of the young pharaoh who ruled during the 18th Dynasty. The tomb's discovery marked a major milestone in Egyptology, as it was one of the few royal tombs found relatively intact."
# }
# Original cell:
# {
#   "entity_name": "Ancient Wars",
#   "detailed_summary": "The Ancient Wars refer to a series of conflicts that took place between Greece and the Persian Empire, primarily during the 5th century BCE. These wars, known as the Greco-Persian Wars, were significant military engagements in ancient history, marking a period of intense struggle for dominance between these two powerful civilizations. The wars began with the Persian invasion of Greece, led by King Darius I, and culminated in the Battle of Plataea, which marked the end of the Persian invasion of Greece and the repulsion of Persian forces from mainland Greece. The Greeks, primarily city-states such as Athens, Sparta, and Thebes, banded together to resist the Persians, demonstrating their resilience and determination. Key battles during these wars include the Battle of Marathon, the Battle of Thermopylae, the Battle of Salamis, and the Battle of Plataea. The Greeks employed the hoplite phalanx formation, a tightly packed infantry formation, in many of these battles, which proved effective against the larger Persian forces. The Ancient Wars played a crucial role in shaping the course of history during the Classical period, with significant implications for the development of Western civilization."
# }
# Original cell:
# {
#   "entity_name": "Animal Behavior",
#   "detailed_summary": "Animal Behavior encompasses a wide range of actions, postures, and communication methods exhibited by various species of animals, particularly cats. Biting, for instance, can signify predation, self-defense, playfulness, or discomfort, depending on the context. Play fighting, a behavior observed in cats, involves pouncing, biting, swatting, and wrestling, serving different purposes in play or real combat. Climbing is a natural instinct for cats, allowing them to navigate and explore their environment effectively. Socialization, a significant behavior, involves interactions between humans and other cats, playing a crucial role in social learning and bonding. The term 'GLARING' refers to a collective group of cats. The toy is an object designed to stimulate a cat's natural hunting instincts. Biting can also be a sign of affection among cats, but understanding the underlying cause for a cat's biting behavior is essential to addressing potential issues. Hunting, a crucial part of a cat's survival, involves sharp claws used to catch and capture prey. Grooming serves various purposes in the feline world, including self-care, maintaining coat health, and social bonding. Redirected Aggression is a form of aggression exhibited by cats towards nearby animals or humans when the original stimuli cannot be attacked. Scent Rubbing is a territorial marking and communication method used by cats. The state of hunger can increase a cat's desire to play. Feline Aggression refers to aggressive behavior exhibited by older cats towards newly arrived kittens, as well as a tendency for cats to direct their anger elsewhere when they cannot attack the stimuli. The Prey entity triggers predatory behavior in cats. Bunting is a behavior exhibited by both domestic cats and other felines, where they head-bump humans or other cats with the front part of their head. Aggressive Behavior refers to a set of actions displayed by cats when they become agitated or threatened. Rubbing and Headbumping Behaviors of cats are methods used to deposit scents on various substrates, including humans. Play is an interactive activity that can be observed in cats, indicated by the cat twitching its tail while engaging in playful behavior. Decay refers to a general period of time when something undergoes deterioration or ceases to exist, in the context of animals, specifically cats, decay can also refer to the deterioration or rotting of their teeth. Stalking is a persistent and focused behavior exhibited by various entities, including cats, characterized by a crouched stance and a low, quick movement of the tail. The Scent Rubbing Behavior is a behavior observed in domestic cats, which is believed to serve as a means of social bonding. Shedding refers to the natural shedding of the outside layer of a cat's claw sheaths when they scratch rough surfaces. String is a type of toy that can potentially pose a danger if ingested by cats. The coyote plays a significant role in the ecosystem by reducing the impact of cat predation. Self-defense refers to a protective activity exhibited by cats, in which they utilize their claws as a means of defense. Human activity plays a significant role in shaping the behavior of house cats. Predatory behavior refers to the hunting and catching of prey, a characteristic exhibited by cats. Dominance refers to a behavior exhibited among domestic cats in multi-cat households, as well as the behavior displayed by conspecifics (members of the same species) to establish a hierarchy or rank among themselves. Raccoons are small predators known to be affected by cat predation. Kittens are young domestic cats that engage in play behavior to learn hunting skills. The Aggressor is a cat that displays aggressive behavior towards another cat. Nose-to-nose touching is a common greeting behavior exhibited by domestic cats. Safety behaviors refer to a set of actions deliberately undertaken by individuals with the primary objective of preventin ...
# }
# Original cell:
# {
#   "entity_name": "Animated Film: Ratatouille",
#   "detailed_summary": "Ratatouille is a critically acclaimed, computer-animated comedy-drama film produced by Pixar Animation Studios and distributed by Walt Disney Pictures. The film, released in 2007, tells the story of Remy, a rat with an exceptional sense of taste who dreams of becoming a renowned chef in a French restaurant. The movie was directed and co-written by Brad Bird, with music composed by Michael Giacchino. The soundtrack, featuring popular tracks like 'Alfredo's Theme' and 'Ratatouille,' enhances the movie's narrative and adds to its overall charm. The film was produced entirely by Pixar Animation Studios and was screened in 3940 theaters during its opening weekend.
#
# Ratatouille received numerous nominations at the 80th Academy Awards, including Best Original Score, Best Sound Editing, and Best Sound Mixing. The film won the Academy Award for Best Animated Feature, recognizing its exceptional animation and storytelling in the animated film industry.
#
# The film's voice cast includes notable actors such as Peter Sohn, Patton Oswalt, Brian Dennehy, Janeane Garofalo, and IAN HOLM, who won the award for Best Voice Acting in an Animated Feature Production for his role as Skinner.
#
# Ratatouille has been referenced in various television shows and media outlets, such as Brooklyn Nine-Nine, TED LASSO, The Good Place, Orange Is the New Black, and The Simpsons, indicating a broader cultural impact and influence. The film's storyline and themes of creativity, passion, and the power of food have resonated with audiences and critics alike, making Ratatouille a beloved and enduring animated film."
# }
# Original cell:
# {
#   "entity_name": "Animated Film Reviews",
#   "detailed_summary": "Animated Film Reviews is a collective of numerous film critics and reviewers who have provided their opinions on various animated films, with a notable focus on the movie Ratatouille. The film received widespread acclaim, as evidenced by the numerous positive reviews it received from critics such as Colin Covert (The Star Tribune), Bill Muller (The Arizona Republic), Scott Foundas (LA Weekly), Roger Ebert (Chicago Sun-Times), Bill Mathews (New York Daily News), Rene Rodriguez (Miami Herald), Steven Rea (The Philadelphia Inquirer), Jack Mathews (New York Daily News), Owen Gleiberman (Entertainment Weekly), Justin Chang (Variety), Roger Moore (The Orlando Sentinel), David Ansen (Newsweek), Peter Hartlaub (San Francisco Chronicle), Liam Lacey (The Globe and Mail), Peter Travers (Rolling Stone), TOM LONG (The Detroit News), and others. The film was reviewed in various publications, including The Star Tribune, The Arizona Republic, LA Weekly, The Chicago Sun-Times, The Philadelphia Inquirer, The New York Daily News, Miami Herald, San Francisco Chronicle, The Globe and Mail, Rolling Stone, The Detroit News, Variety, Entertainment Weekly, Newsweek, The Wall Street Journal, The Los Angeles Times, The Washington Post, The Denver Post, The Chicago Reader, USA TODAY, and ReelViews. Ratatouille was awarded various ratings, with some critics, such as James Berardinelli, giving it three out of four stars, while others, like Colin Covert and Bill Muller, gave it four out of four stars. The film's positive reception can be attributed to its engaging storyline, strong characters, and overall quality, as reflected in the numerous positive reviews it received."
# }
# Original cell:
# {
#   "entity_name": "Animation - Aladdin",
#   "detailed_summary": "Aladdin is a popular and enduring character from the Middle-Eastern folk tale that is one of the best-known tales associated with One Thousand and One Nights. The story revolves around Aladdin, a street urchin who stumbles upon a magical lamp containing a genie. The genie grants Aladdin three wishes, which he uses to become rich and powerful, eventually marrying the princess and becoming a king. This classic tale has been adapted into various forms of media, including manga, anime, films, musicals, and video games. Notable adaptations include the 1992 animated feature film produced by Walt Disney Feature Animation, which is currently the most recognized retelling of the story. Other adaptations include the 1970 French animated feature film Aladdin and his Wonderful Lamp, the 1982 Toei Animation adaptation directed by Yoshikatsu Kasai, and the 1993 French animated series Les Mille et Une Nuits. The story has also been incorporated into other works, such as the Japanese television series Kyoryu Sentai Zyuranger and the Italian production Superfantagenio. Aladdin has been featured in various media, including pachinko machines, children's musicals, and video games. For instance, Sega Sammy has released a line of Aladdin-themed pachinko machines, and Anuman Interactive released a hidden object game titled Aladin and the Enchanted Lamp. The story has also been adapted for younger audiences, such as in the children's musical Aladdin JR. The character Aladdin has been portrayed by various voice actors, including KAORI ISHIHARA in the anime adaptation of Magi: The Labyrinth of Magic."
# }
# Original cell:
# {
#   "entity_name": "Arabic Dialects",
#   "detailed_summary": "Arabic Dialects refer to the various regional and local languages spoken across different geographical areas, which are not mutually comprehensible with Modern Standard Arabic. These dialects are primarily used in everyday conversations among families and communities within their respective regions. Arabic Dialects exhibit unique phonetic, morphological, and syntactic features that distinguish them from each other and from Classical Arabic. Examples of Arabic Dialects include Levantine Arabic, Jordanian Arabic, Najdi Arabic, Saharan Arabic, South Mesopotamian Arabic, Gulf Arabic, Hassaniya Arabic, Khorasani Arabic, Judeo-Mesopotamian Arabic, Juba Arabic, Cypriot Maronite Arabic, Shirvani Arabic, Safaitic, and many others. These dialects play a crucial role in preserving local identities and traditions, reflecting the rich cultural heritage and complex history of the Arab world. Some dialects, such as Shirvani Arabic and Ani Arabic, are now considered extinct, while others, like Maghrebi Arabic and Egyptian Arabic, continue to be widely spoken. The diversity within Arabic Dialects is a testament to the linguistic richness and complexity of the Arab world."
# }
# Original cell:
# {
#   "entity_name": "Arabic Scholars",
#   "detailed_summary": "Arabic Scholars are a diverse group of individuals who have made significant contributions to the Arabic language and its literature throughout history. Their work spans various domains, including linguistics, literature, and religious studies. Some notable scholars include Khalil Ibn Ahmad Al Farahidi, who standardized the Arabic script in 786, Ibn Mada of Cordoba, who realized the overhaul of Arabic grammar proposed by Al-Jahiz 200 years prior, and Ibn Manzur, who authored the comprehensive Lisān al-ʿArab lexicon. Other scholars have focused on the study of Quranic healing (Alean Alkrenawi), the development of Arabic dictionaries (Al-Khalil ibn Ahmad al-Farahidi, author of Kitab al-'Ayn, and Ibrāhīm Abd al-Ghaffār Addasūqī, who collaborated with Edward William Lane on the Arabic–English Lexicon), and the promotion of Romanization (Ahmad Lutfi as Sayid, Muhammad Azmi, and Louis Massignon). Additionally, there are scholars who have played a role in the establishment of academies for Arabization, such as Rifa'a Altahtawi, who led the establishment of Madrasat al-Alsun in 1836, and the Educational, Cultural, and Scientific Organization of the Arab League, which established a bureau for standardizing Arabization in 1997. These scholars have played a crucial role in preserving, promoting, and advancing the Arabic language and its literature."
# }
# Original cell:
# {
#   "entity_name": "Architecture",
#   "detailed_summary": "Architecture, as demonstrated in the provided descriptions, encompasses a wide range of styles, designs, and influences. It serves as a canvas for artistic movements, such as Art Nouveau, which was prominently featured in the Palacio de Bellas Artes. This style, characterized by intricate patterns and organic forms, was introduced into the design of this architectural masterpiece. Other structures, like the Amiens Cathedral and the Nauvoo Illinois Temple, showcase unique architectural designs that incorporate symbolic motifs, such as pentagrams and five-pointed stars. These symbols add an element of mystery and complexity to the overall aesthetic of these structures. Additionally, architecture can be found in various types of buildings, including palaces, cathedrals, castles, and halls. These buildings often share common design features, such as spiral staircases, which suggest a common design influence or practical application across these distinct types of structures. Furthermore, architecture can also house significant cultural artifacts, such as the Forbes Pipe Organ, which adds an air of elegance and historical significance to the location. Organizations like ISPO play a crucial role in promoting music and cultural activities within their communities, as evidenced by their hosting of events like the opening concert of the Forbes Pipe Organ."
# }
# Original cell:
# {
#   "entity_name": "Art Deco Architecture",
#   "detailed_summary": "Art Deco Architecture is a distinctive and visually striking architectural and artistic movement that emerged in the 1920s. Characterized by its bold geometric shapes, rich colors, and lavish ornamentation, Art Deco represents an eclectic aesthetic that draws inspiration from various sources such as Egyptian, Aztec, and Mayan art, as well as Cubism and Futurism. This style is often associated with luxury, glamour, and the machine age, making it a popular choice for high-end residential buildings, hotels, and public spaces during its heyday. The Art Deco movement had a significant impact on various forms of design, including architecture, interior design, fashion, and graphic arts, leaving an indelible mark on the cultural landscape of the 20th century. Notable examples of Art Deco architecture can be found in the Palacio de Bellas Artes."
# }
# Original cell:
# {
#   "entity_name": "Art and Literature in Mexico",
#   "detailed_summary": "Art and Literature in Mexico is a rich and diverse cultural landscape, with significant contributions from various artists, writers, architects, and intellectuals. This entity encompasses a wide range of artistic expressions, from murals and sculptures to novels, poetry, and plays.
#
# Prominent figures in Mexican muralism, often referred to as the 'Big Three,' include Diego Rivera, José Clemente Orozco, and David Alfaro Siqueiros. These artists were commissioned by the Mexican government to create large-scale historical murals on public buildings, leaving an indelible mark on the country's architectural landscape.
#
# In the literary field, notable authors include Octavio Paz, Carlos Fuentes, Ignacio Manuel Altamirano, and Juan Ruiz de Alarcón. Paz is renowned for his exploration of the concept of a Mexican national character, while Fuentes is recognized for his literary works. Altamirano made significant contributions during the 19th century, and Alarcón was a significant figure during the Baroque literature period in 17th century Mexico.
#
# Other notable literary works include 'The Labyrinth of Solitude' by Octavio Paz, 'Los de abajo' by Mariano Azuela, and 'Pedro Páramo' by Juan Rulfo. These works provide insightful portrayals of Mexican culture, history, and society.
#
# In the culinary realm, Elena Reygadas is recognized as the best female chef in the world, underscoring her exceptional skills and contributions to the gastronomic industry.
#
# Architects such as Enrique del Moral, Mario Pani, and Luis Barragán have also made significant contributions to the urban landscape of Mexico City, particularly in Ciudad Universitaria. Their work has left an indelible mark on the city's university district.
#
# Moreover, Mexico has been home to renowned poets such as Pablo Neruda and Gabriela Mistral, who were born in Chile. The country also has a substantial number of Mexicans residing there.
#
# It is also worth noting that Mexico has a vibrant countercultural and political movement known as La Onda, which originated from the Mexican rock culture of the late 1960s. This movement serves as a platform for artistic expression, political activism, and cultural exchange within the Mexican community.
#
# Frida Kahlo, a female artist of significant historical importance, is renowned for her largely personal portraiture, which is considered the most important historical contribution by a female artist to date."
# }
# Original cell:
# {
#   "entity_name": "Artificial Intelligence",
#   "detailed_summary": "Artificial Intelligence (AI) is a rapidly evolving technology with significant advancements and applications across various industries. In October 2022, DeepMind, a leading AI company owned by Alphabet Inc., released AlphaTensor, a neuro-symbolic AI that utilizes reinforcement learning to solve mathematical problems. This tool was designed to discover novel algorithms for matrix multiplication in mathematics, demonstrating its potential in advancing mathematical research and optimizing computational processes. DeepMind is also known for developing AlphaGo, an AI system that defeated a world champion Go player in 2016. Other AI systems developed by DeepMind include MuZero, which learns without being explicitly taught the rules, and the Flamingo, a visual language model that accurately describes pictures with minimal training images. Google, another major player in AI, developed Tensor Processing Units (TPUs) to enhance the performance of machine learning models. These units have been utilized in Google's AI systems, such as AlphaGo Zero and MuZero. IBM, another significant contributor to AI, developed Deep Blue, a chess-playing computer that famously defeated Garry Kasparov in 1997. AI has also been applied in healthcare, with DeepMind collaborating with the Royal Free NHS Foundation Trust to develop the Streams app, which helps diagnose acute kidney injury. The integration of AI in healthcare is expected to enhance patient care and outcomes. AI has also been used in archaeology document restoration, with Ithaca, a deep neural network developed by Google, assisting researchers in restoring damaged Greek documents. The ethical implications of AI are being addressed by entities like the DeepMind Ethics and Society Board, which aims to ensure that AI development aligns with societal values and promotes responsible use of AI technology for the betterment of humanity. AI is also being integrated into traditional programming libraries, as evidenced by the first update involving an algorithm discovered using AI being made to the C++ Standard Library sorting algorithms."
# }
# Original cell:
# {
#   "entity_name": "Artificial Intelligence (2) - AlphaGo",
#   "detailed_summary": "Artificial Intelligence (2), primarily recognized as AlphaGo, is a groundbreaking AI system developed by DeepMind Technologies. It made headlines in 2016 when it defeated the world champion Go player, Ke Jie, in a five-game match, marking a significant milestone in AI history. AlphaGo is an advanced computer program that excels at the game of Go, a complex board game originating from China. It was designed based on deep reinforcement learning, using a combination of machine learning and tree search techniques, combined with extensive training, both from human and computer play. AlphaGo's development and impact on the field of AI were showcased in the documentary film 'Alphago' and the documentary 'The Master of Go'. AlphaGo Master, an updated version of the AI, was used in a game against Tang Weixing and played games on the FoxGo server, indicating its versatility and adaptability across different platforms. AlphaGo Zero, a self-taught AI system developed by DeepMind, surpassed the strength of AlphaGo in just three days, demonstrating superhuman abilities not only in the game of Go but also in chess and shogi. The SENSEIS LIBRARY serves as a valuable platform for enthusiasts and researchers interested in the field of artificial intelligence, particularly in relation to Go games, hosting links to AlphaGo games and functioning as a hub for the AlphaGo wiki. AlphaGo's performance at the International Mathematical Olympiad (IMO) in 2024, where it reached a level equivalent to that of a silver medalist, underscores its proficiency in solving complex mathematical problems at an international level. AlphaGo's victory against Go champion Fan Hui in March 2016 marked a major breakthrough as Go is considered one of the most complex board games due to its vast number of possible moves and strategies. AlphaGo's ability to learn complex games from scratch without human guidance or pre-existing knowledge, as demonstrated by AlphaGo Zero, represents a significant advancement in AI's ability to master complex games like Go."
# }
# Original cell:
# {
#   "entity_name": "Astronomy",
#   "detailed_summary": "Astronomy is the scientific study of celestial objects and the universe as a whole. It encompasses various phenomena beyond Earth's atmosphere, including stars, planets, comets, galaxies, and other celestial bodies. Astronomy also investigates the fundamental laws that govern their behavior and interactions within the cosmos. Some aspects of astronomy, such as the application of the yin-yang theory, are rooted in ancient Chinese philosophy. This field is crucial for understanding the origins and evolution of the universe, as well as the potential existence of extraterrestrial life. However, it is important to note that certain theories, such as the Nibiru hypothesis, lack empirical evidence and are not widely accepted within the scientific community."
# }
# Original cell:
# {
#   "entity_name": "Autobahn",
#   "detailed_summary": "The Autobahn is a network of high-speed motorways in Germany, initially built for military purposes but later used primarily for civilian transportation. This extensive road system, renowned for its lack of speed limits on many sections, serves as the country's primary means of long-distance travel, connecting major cities and regions. The Autobahn is a crucial part of Germany's infrastructure, with unique traffic rules and tolls collected for heavy vehicles on certain sections. It is important to note that the Autobahn is a type of highway in Germany, making it a significant component of the country's overall road system. The Autobahn network spans approximately 13,192 kilometres (8,197 miles) as of 2021. The Autobahn network is equipped with various facilities such as parking rest areas for trucks, rest areas, emergency telephones, and dynamic traffic guidance systems to ensure convenience and safety for travelers. The Autobahn system has faced challenges such as unfinished projects, speed limit discussions, and safety concerns, but it remains a significant part of Germany's transportation infrastructure."
# }
# Original cell:
# {
#   "entity_name": "Autobahns",
#   "detailed_summary": "Autobahns are high-speed German motorways known for their lack of general speed limits, although a minimum advisory speed limit of 60 KMH is set on these specific roadways. These highways are designed for vehicles with top speeds greater than 60 km/h, including cars and heavy-duty trucks, which have a maximum design speed of 62 km/h. However, many drivers often exceed this limit, making the autobahn a unique driving experience compared to other road networks worldwide. Motorcycles, scooters with low engine capacity, and microcars are not permitted on the autobahn due to safety concerns. Quads and vehicles with a top speed less than 60 km/h are also prohibited. Construction sites, areas with steep terrain, and certain sections of the autobahn may have lower speed limits for safety reasons. The police enforce traffic rules and regulations on the autobahn, although they are not universally trusted by citizens. Petrol stations are strategically located approximately every 50–55 kilometers on the autobahn to prevent motorists from running out of fuel while traveling long distances. The autobahn network is monitored using speed detection loops, and the House of the German Parliament makes decisions related to speed limits. The UNLIMITED HIGHWAYS in Germany are unique stretches of road that do not have speed limits, offering drivers the freedom to travel at their desired speeds within certain guidelines and conditions. The autobahn system is a significant part of the German highway system, with highways like A9 featuring high speed limits of 130 km/h."
# }
# Original cell:
# {
#   "entity_name": "Automotive Industry in Mexico",
#   "detailed_summary": "The Automotive Industry in Mexico is a significant sector, leading among North American nations in the production of automobiles. This industry plays a crucial role in the country's economy, accounting for approximately 33% of its total output. The industry's growth and development can be traced back to the 1930s, with companies such as General Motors, Volkswagen, Chrysler, and Audi establishing their operations in Mexico during this period. These multinational corporations have contributed significantly to the industry's growth over several decades. The city of Puebla, in particular, serves as a hub for approximately 70 industrial part-makers, with a significant concentration of these businesses clustering around Volkswagen, suggesting that the city plays a crucial role in the automotive industry supply chain. The industry is also supported by the National Polytechnic Institute, a prominent public university located in Mexico, which serves as a significant educational institution within the country's higher education system. The Asia-Pacific Economic Cooperation Forum (APEC), to which Mexico is a member, also promotes economic integration among Asian countries and Pacific Rim countries, potentially offering opportunities for further growth and expansion for the Mexican automotive industry. However, the industry faces challenges such as competition from other countries and ongoing infighting within drug trafficking organizations like the Gulf Cartel, which can impact the region's stability and security."
# }
# Original cell:
# {
#   "entity_name": "Aviation",
# ...
#   "detailed_summary": "Triumph, as inferred from the provided descriptions, represents a recurring theme and narrative structure in various stories, particularly those classified under the ATU Type 510A, such as Cinderella. This theme revolves around a young protagonist who faces adversity and hardship at the hands of cruel family members or others, but ultimately triumphs through kindness, wit, and perseverance. This theme is present in stories like 'The Story of Tam and Cam', 'The Wonderful Birch', and 'Geekerella', among others. The 'Persecuted Heroine' category, as defined by the AARNE-THOMPSON-UTHER SYSTEM, encompasses these narratives. Characters like Allerleirauh, The Wonderful Birch, and Rushen Coatie are examples of individuals who embody this theme of triumph in the face of adversity. Additionally, the JT9D7A engine, while not directly related to the theme of triumph, is used to power the aircraft, symbolizing the engine's role in enabling the aircraft to soar, which can be metaphorically linked to the theme of triumph."
# }
# Original cell:
# {
#   "entity_name": "Elvis Crespo",
#   "detailed_summary": "Elvis Crespo is an American singer, born in Guaynabo, Puerto Rico, who gained significant popularity with his contributions to the Merengue genre. He is renowned for his debut album SUAVEMENTE, released in 1998, which was a hit both in Latin America and the US, earning him the Tropical: Album of the Year award in 1999. Throughout his illustrious career, Crespo has released numerous albums such as SABORÉALO (2004), ONE FLAG (2013), TATUAJE (2015), WOW FLASH (2000), Urbano (2002), DIOMEDIZAO (2018), and REGRESÓ EL JEFE (2007, 2021). His album Multitudes (2021) marks a significant contribution to his discography, showcasing his continued dedication to Latin music and its diverse rhythms. Crespo's album PINTAME, released in 1999, was highly acclaimed, winning both Tropical Album of the Year and Tropical Song of the Year awards in 2000. It is worth noting that he was previously associated with the musical group GRUPO MANIA before embarking on his solo career. However, there is no direct connection established between Crespo and the group of entities named LOS MONSTERS. Crespo's music has made an impact not only within the Latin music community but also on the US market, setting a record for holding the top position on Billboard's Hot Latin Tracks chart. Despite his success, Crespo has faced allegations, leading to investigations by both the Miami-Dade Police Department and the FBI."
# }
# Original cell:
# {
#   "entity_name": "Umbanda",
#   "detailed_summary": "Umbanda is an Afro-Brazilian folk religion that emerged in the early 20th century and has since grown into a significant cultural and spiritual movement within Brazil. It is characterized by the practice of spirit possession, where a person's body is temporarily controlled by a spirit during trance states. This syncretic religion combines elements from various religious traditions such as Catholicism, Candomblé, and Spiritism. Umbanda is known for its association with trance-possession states, which are considered integral to the religion and are associated with specific documentation (document ID 7290b6f0-e3fc-47f6-b802-b1b9a9e7fad3, chunk ID dffca419-8d4f-44ea-9c96-2f313b59183a). The practice of Umbanda has been reported among African-Americans in the United States, particularly in the context of Hoodoo, a unique culture deeply rooted in African spiritual practices (implicit). Umbanda is also known to have connections with other spirit-possession-based religions and beliefs across Africa, such as those found among the Sidama people in Southwest Ethiopia (document ID 7290b6f0-e3fc-47f6-b802-b1b9a9e7fad3, Chunk ID cb1848ce-80f9-4fe3-9e24-dc2ecd71f384), the Xesibe people in Transkei, South Africa, and the Sukuma people in Tanzania."
# }
# Original cell:
# {
#   "entity_name": "University",
#   "detailed_summary": "A university is a higher education institution that serves as a hub for academic, research, and cultural activities. Examples of universities include Rutgers University, Charles University in Prague, The Hebrew University of Jerusalem, Harvard-Westlake School, Queens, Robert Wood Johnson Medical School (part of Rutgers University), Colorado College, The University of Cambridge, Johns Hopkins University, Harvard Law School, The University of Melbourne, Princeton University, The University College London, Imperial College London, Glasgow Caledonian University, Adelaide University, Stanford University, Tufts University, The Massachusetts Institute of Technology (MIT), Georgetown University, and many others. Universities offer a wide range of programs, from undergraduate to postgraduate studies, in various fields such as mathematics, law, medicine, computer science, and arts. Some universities also house museums, theaters, and other cultural institutions. For instance, Rutgers University has the Zimmerli Art Museum, the Art Museum at Rutgers University, and several student-run theater companies. Universities also play a significant role in research and innovation, with scholars and researchers contributing to advancements in various fields. For example, Neil Lawrence holds a chair in machine learning at the University of Cambridge, and Elon Lindenstrauss is a professor at Princeton University. Universities also serve as alma maters for many notable individuals, such as Bery Perkins, who graduated from Harvard-Westlake School and Brown University, and William Marston, who graduated from Harvard Law School. Some universities have historical significance, such as Rutgers University, which was originally established as Queen's College in 1766 and has faced periods of closure and reopening. Universities also play a role in the local community, providing healthcare services (e.g., Rutgers Robert Wood Johnson University Hospital), and hosting cultural events (e.g., the Rutgers Film Co-op/New Jersey Media Arts Center's film festivals)."
# }
# Original cell:
# {
#   "entity_name": "Vampire Folklore",
#   "detailed_summary": "Vampire Folklore refers to a rich and diverse collection of legends, myths, and superstitions that have been passed down through generations, primarily originating from European cultures. These stories often depict vampires as undead beings that prey on the living, transforming into bats or wolves, and possessing an aversion to sunlight. The legends vary across different regions, with each culture adding its unique twist to the vampire lore. Some notable examples include Bram Stoker's Dracula, based on the historical figure Vlad the Impaler, and the Romanian folklore about Strigoi. The physical characteristics of a vampire, as described, may include the seeping of blood from the mouth and nose, the growth of teeth, hair, and nails, and a bloated appearance after consuming blood. The belief in vampires was widespread during the 18th century and was linked to rabies. In some cultures, vampires were associated with specific diseases, such as tuberculosis in New England. Vampires were also believed to be repelled by mirrors placed facing outwards on a door and warded off by items like garlic and the linen shroud. The origins of vampire beliefs can be traced back to ancient Greek mythology, medieval Europe, and Eastern European cultures. The belief in vampires persisted well into the modern era, particularly in the Balkan region, and was often associated with individuals who died violently or under unusual circumstances. The mythology surrounding vampires has been a significant influence on popular culture, shaping literature, films, television shows, and video games."
# }
# Original cell:
# {
#   "entity_name": "Vampires",
#   "detailed_summary": "Vampires are supernatural beings that have been a significant part of literature, film, and popular culture since the 19th century. The modern vampire legend was largely shaped by Bram Stoker's novel 'Dracula', published in 1897, which introduced the character of Count Dracula and popularized the use of mirrors as a means to ward off vampires. Other influential works include John Polidori's 'The Vampyre' and James Malcolm Rymer and Thomas Peckett Prest's 'Varney the Vampire'. Vampires are typically depicted as undead beings with supernatural powers, such as the ability to transform into bats, animals, or mist, and an aversion to sunlight, running water, and religious symbols. They are often portrayed as blood-sucking creatures that prey on humans, but can also be depicted as having vulnerabilities, such as Count Orlok of Murnaus' dependence on his native Transylvanian soil to transform. Notable fictional vampires include Lord Ruthven, Count Dracula, and Blade. The vampire mythos has been adapted and reinterpreted in various media, including films, television series, video games, and novels, with notable examples including 'Nosferatu', 'Dark Shadows', 'Castlevania', and 'Buffy the Vampire Slayer'. Real-life individuals, such as Peter Kürten and Richard Trenton Chase, have also been associated with the vampire mythos due to their macabre practices."
# }
# Original cell:
# {
#   "entity_name": "Vampires (2)",
#   "detailed_summary": "Vampires (2) is a multifaceted entity that has been a subject of folklore, superstition, and contemporary subculture across various regions and time periods. The term refers to mythical beings that are often associated with the consumption of human blood, though this practice is distinct from traditional vampire folklore. In some cultures, such as the Afrikaans-speaking families in South Africa, a unique tradition involves leaving teeth in a shoe for the Tandemuis. This practice is consistent across various sources, indicating its widespread observation. In Southeastern Europe, hawthorn stakes were traditionally employed as a means to destroy vampires, reflecting the deep-rooted superstitions and beliefs surrounding these creatures in local culture. In Serbia, aspen stakes were used in vampire mythology, adding an intriguing layer to the country's historical and folkloric identity. In certain cultures, consuming flour or drinking it was believed to offer protection against vampires, though this belief lacks scientific evidence. In some regions, such as Rhode Island and Eastern Connecticut in the United States, belief in vampires was prevalent during certain periods. In Europe, notable figures like Empress Maria Theresa and Michael P Fay were associated with investigations into claims of vampirism. Notable cases include the Arnold Paole Case and the alleged vampire haunting at Highgate Cemetery in London. In contemporary times, there exists a subculture known as Sianguiistic Vampirism, where individuals engage in the consumption of others' blood as a pastime. It is important to note that these practices and beliefs should not be relied upon as a means of protection against real-life individuals claiming to be vampires, as there is no scientific evidence supporting their effectiveness."
# }
# Original cell:
# {
#   "entity_name": "Vietnamese Pop Music",
#   "detailed_summary": "Vietnamese Pop Music is a genre of Mandarin-language popular music that originates from Taiwan, China, with unique elements and variations specific to Vietnamese culture and folklore. It is characterized by its unique blend of traditional Taiwanese and Chinese influences with contemporary Western elements, creating a distinct sound that sets it apart from other forms of Mandarin pop. The genre has gained significant popularity both domestically and internationally, with numerous artists achieving commercial success and critical acclaim. However, it is important to note that during the Vietnam War, popular music known as yellow music was banned after the Fall of Saigon in 1975 due to its association with South Vietnam and opposition to red music endorsed by the Communist government of North Vietnam. Additionally, music censorship is a practice that has been observed in Vietnam, as evidenced by the conviction of British musician Gary Glitter for child sexual abuse. Furthermore, during the French colonial period, Vietnam adopted Right-Hand Drive (RHT) as its driving system, which is an unusual practice compared to most countries that use Left-Hand Drive (LHD)."
# }
# Original cell:
# {
#   "entity_name": "War",
#   "detailed_summary": "War is a significant historical entity characterized by military conflicts between nations, groups, or ideologies. These conflicts have occurred throughout history, with various causes such as territorial disputes, political tensions, economic interests, and ideological differences. The duration of wars can vary significantly, from brief skirmishes to prolonged conflicts spanning decades. Wars have had profound impacts on the course of history, shaping political landscapes, borders, and societal structures. They have also resulted in significant loss of life and destruction. Examples of wars include the American Revolution, the Mexican-American War, the First Schleswig War, the Falklands War, the Texas Revolution, the First Opium War, the Spanish Conquest of Tripoli, the Reconquista, the War of the Golden Stool, the Anglo-Zanzibar War, the Chilean Civil War, the War of the Pacific, the Quasi-War, the Second Melillan Campaign, the Peasants' War, the Spanish-American War, the Anglo-Spanish War, the Second Schleswig War, the Hundred Years War, the World War II, and many others. Wars have also played a crucial role in shaping international relations and have led to the signing of treaties and the establishment of alliances."
# }
# Original cell:
# {
#   "entity_name": "Water",
#   "detailed_summary": "Water is a liquid that is essential for various life forms, including humans and cats. It is a key component of the Earth's ecosystem, serving as a significant natural feature in the form of oceans, lakes, rivers, and other inland water bodies. Water plays a crucial role in maintaining homeostasis by removing waste products and excess water from the body. It is also used in various applications such as irrigation, water supply systems, and industrial processes. In addition, water is used in chemical laboratories for storing, mixing, and heating chemicals. It is also a common ingredient in various foods and beverages. Water can be found in various states, including solid (ice) and vapor (steam). It is also a medium for swimming and other aquatic activities. It is important to note that water in swimming pools can become contaminated with urine, which can lead to poor water quality and increased levels of chloramines. Water can also be a hazard in certain situations, such as sudden immersion in freezing water, which can trigger a cold shock response and potentially lead to death. Water is also used in alternative medicine practices such as the gallbladder flush. It is also used in urine therapy for treating jellyfish stings."
# }
# Original cell:
# {
#   "entity_name": "Weather",
#   "detailed_summary": "The entity 'Weather' encompasses a wide range of atmospheric conditions, including temperature. The average internal temperature of the human body, a key aspect of weather, is consistently 36.4 degrees Celsius (97.5 degrees Fahrenheit), with small fluctuations across various sources and documents. This temperature remains relatively stable despite minor variations. However, it is essential to acknowledge that the previously accepted average body temperature of 98.6 degrees Fahrenheit (37 degrees Celsius) was revised through modern research, as it was initially derived from an 1860 study. The room temperature, considered comfortable for human habitation, typically ranges between 15-24 degrees Celsius (60-75 degrees Fahrenheit). On the other extreme, the Oran Desert is renowned for its exceptionally high temperatures, which can soar as high as 50°C (122°F), making it one of the hottest regions on record. The temperature of 16,424 feet (5,006 meters) during a specific flight instance in 1830-1831 is also a notable weather-related detail."
# }

# %%
df_combined = pd.DataFrame(Dict_cs)
df_combined.to_csv('/Users/mogen/AdvancedRag/Clustered_nomic/_medium_level_community_summaries.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_combined = pd.DataFrame(Dict_cs)
#       2 df_combined.to_csv('/Users/mogen/AdvancedRag/Clustered_nomic/_medium_level_community_summaries.csv')
#
# NameError: name 'Dict_cs' is not defined

# %%
combined_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 combined_dict
#
# NameError: name 'combined_dict' is not defined

# %%
path= '/Users/mogen/AdvancedRag/Clustered_nomic/df_inspect.csv'
Cluster_group= pd.read_csv(path)
Cluster_group.head()
# Out:
#             Nomic Topic: broad  \
# 0  Artificial Intelligence (3)
# 1            Behavioral Health
# 2     Classic Animated Stories
# 3                Languages (2)
# 4              Mexican Cuisine
#
#                                                    0
# 0  Polygraph Tests, Artificial Intelligence, Psyc...
# 1  Medicine (3), Legal Proceedings, Carpets, Floo...
# 2  Music, Literature (2), Cinderella Film, Publis...
# 3  Arabic Scholars, Arabic Dialects, Linguistics,...
# 4  Art and Literature, Biodiversity, Political Le...

# %%
len(Cluster_group )
# Out:
# 8

# %%
# Assuming you have two dataframes: cluster_group and df_combined

# Initialize lists
list1 = []
list2 = []

# Iterate through each row in '0' column of cluster_group
for labels in Cluster_group['0']:
    # Split comma-separated labels
    label_list = [label.strip() for label in labels.split(',')]
    
    # Process each label
    for label in label_list:
        # Look up the label in df_combined['entity_name']
        matching_row = df_combined[df_combined['entity_name'] == label]
        
        # If found, take the corresponding value from 'detailed_summary' and append to list1
        if not matching_row.empty:
            detailed_summary = matching_row['detailed_summary'].values[0]
            list1.append(detailed_summary)
    
    # Append the original list of labels to list2
    list2.append(list1)
    list1=[]

# Display the two lists
print(len(list2))
print(list2)
# Out:
# 8
# [["Polygraph Tests, also known as lie detectors, are devices used to assess truthfulness by measuring physiological responses such as heart rate, blood pressure, and sweat gland activity. Their use varies across countries, with some employing them in criminal investigations and employment vetting processes, while others have stricter regulations or outright bans due to concerns about their reliability. The technology's origins can be traced back to the work of John Augustus Larson and his wife Elizabeth Holloway Marston, who made significant contributions to its development. Leonarde Keeler later updated the device in 1939, making it portable and incorporating the galvanic skin response feature. The MACKENZIELEWIS POLYGRAPH is another multifunctional device that serves as a polygraph, measuring breathing patterns and changes in heart rate, blood pressure, and respiration. Law enforcement agencies in the United States are significant users of polygraph technology, although the extent and frequency of its usage are not fully documented. The Supreme Court of the United States has left it up to individual jurisdictions whether polygraph results could be admitted as evidence in court cases. However, in many countries, including Israel, Canada, England, and Wales, polygraph evidence is not admissible in court proceedings. The Employee Polygraph Protection Act of 1988 in the United States generally prohibits employers from using lie detector tests for pre-employment screening or during the course of employment. The use of polygraphs in national security matters aims to maintain the integrity and confidentiality of classified information. Critics such as Doug Williams and George Maschke have expressed skepticism and concerns about the reliability and validity of polygraph examinations. The National Academy of Sciences Report on Polygraph Testing provides comprehensive insights into the use and effectiveness of polygraph testing, offering valuable information for those interested in understanding its applications and limitations.", "Artificial Intelligence (AI) is a rapidly evolving technology with significant advancements and applications across various industries. In October 2022, DeepMind, a leading AI company owned by Alphabet Inc., released AlphaTensor, a neuro-symbolic AI that utilizes reinforcement learning to solve mathematical problems. This tool was designed to discover novel algorithms for matrix multiplication in mathematics, demonstrating its potential in advancing mathematical research and optimizing computational processes. DeepMind is also known for developing AlphaGo, an AI system that defeated a world champion Go player in 2016. Other AI systems developed by DeepMind include MuZero, which learns without being explicitly taught the rules, and the Flamingo, a visual language model that accurately describes pictures with minimal training images. Google, another major player in AI, developed Tensor Processing Units (TPUs) to enhance the performance of machine learning models. These units have been utilized in Google's AI systems, such as AlphaGo Zero and MuZero. IBM, another significant contributor to AI, developed Deep Blue, a chess-playing computer that famously defeated Garry Kasparov in 1997. AI has also been applied in healthcare, with DeepMind collaborating with the Royal Free NHS Foundation Trust to develop the Streams app, which helps diagnose acute kidney injury. The integration of AI in healthcare is expected to enhance patient care and outcomes. AI has also been used in archaeology document restoration, with Ithaca, a deep neural network developed by Google, assisting researchers in restoring damaged Greek documents. The ethical implications of AI are being addressed by entities like the DeepMind Ethics and Society Board, which aims to ensure that AI development aligns with societal values and promotes responsible use of AI technology for the betterment of humanity. AI is also being integrated into traditional  ...

# %%
Cluster_group.head()
# Out:
#             Nomic Topic: broad  \
# 0  Artificial Intelligence (3)
# 1            Behavioral Health
# 2     Classic Animated Stories
# 3                Languages (2)
# 4              Mexican Cuisine
#
#                                                    0  \
# 0  Polygraph Tests, Artificial Intelligence, Psyc...
# 1  Medicine (3), Legal Proceedings, Carpets, Floo...
# 2  Music, Literature (2), Cinderella Film, Publis...
# 3  Arabic Scholars, Arabic Dialects, Linguistics,...
# 4  Art and Literature, Biodiversity, Political Le...
#
#                                        all_summaries
# 0  [Polygraph Tests, also known as lie detectors,...
# 1  [Medicine (3) refers to a diverse and flexible...
# 2  [Music is a diverse and influential entity enc...
# 3  [Arabic Scholars are a diverse group of indivi...
# 4  [The Political Leader entity encompasses a div...

# %%
def generate_prompt(row):
    entity_name = row['Nomic Topic: broad']
    descriptions = row['all_summaries']
    
    # Start building the prompt
    prompt = f"""
You are an expert summarizer tasked with analyzing a set of entity summaries. Your goal is to generate a comprehensive and detailed summary for the entity "{entity_name}" which represents a high-level community of topics. The following descriptions represent summaries of sub-entities within this broader entity.

- Carefully merge the information from all the provided sub-entity summaries into a single cohesive summary.
- Preserve as much relevant detail as possible from each sub-entity summary.
- Identify and clearly state any implicit knowledge or insights that may not be explicitly mentioned but can be inferred from the context.
- Ensure that the summary highlights the key attributes, relationships, and connections between the sub-entities, showing how they collectively contribute to the high-level community of topics.

Entity Name:
"{entity_name}"

Sub-Entity Summariesn"""z
    
    # Add each summary to the prompt
    for i, description in enumerate(descriptions, 1):
        prompt += f"{i}. {description}\n"
    
    prompt += f"\n**Output Format (Dictionary):**\n\n{{\n  'entity_name': '{entity_name}',\n  'detailed_summary': '[Generated detailed summary merging explicit and implicit details from all sub-entity descriptions, showing their connections and contributions to the high-level community of topics]'\n}}\n"
    
    return prompt

# Apply the function to each row in the dataframe
Cluster_group['formatted_prompt'] = Cluster_group.apply(generate_prompt, axis=1)
Cluster_group['formatted_prompt'][0]
# Out:
# '\nYou are an expert summarizer tasked with analyzing a set of entity summaries. Your goal is to generate a comprehensive and detailed summary for the entity "Artificial Intelligence (3)" which represents a high-level community of topics. The following descriptions represent summaries of sub-entities within this broader entity.\n\n- Carefully merge the information from all the provided sub-entity summaries into a single cohesive summary.\n- Preserve as much relevant detail as possible from each sub-entity summary.\n- Identify and clearly state any implicit knowledge or insights that may not be explicitly mentioned but can be inferred from the context.\n- Ensure that the summary highlights the key attributes, relationships, and connections between the sub-entities, showing how they collectively contribute to the high-level community of topics.\n\n**Entity Name:**\n"Artificial Intelligence (3)"\n\n**Sub-Entity Summaries:**\n1. Polygraph Tests, also known as lie detectors, are devices used to assess truthfulness by measuring physiological responses such as heart rate, blood pressure, and sweat gland activity. Their use varies across countries, with some employing them in criminal investigations and employment vetting processes, while others have stricter regulations or outright bans due to concerns about their reliability. The technology\'s origins can be traced back to the work of John Augustus Larson and his wife Elizabeth Holloway Marston, who made significant contributions to its development. Leonarde Keeler later updated the device in 1939, making it portable and incorporating the galvanic skin response feature. The MACKENZIELEWIS POLYGRAPH is another multifunctional device that serves as a polygraph, measuring breathing patterns and changes in heart rate, blood pressure, and respiration. Law enforcement agencies in the United States are significant users of polygraph technology, although the extent and frequency of its usage are not fully documented. The Supreme Court of the United States has left it up to individual jurisdictions whether polygraph results could be admitted as evidence in court cases. However, in many countries, including Israel, Canada, England, and Wales, polygraph evidence is not admissible in court proceedings. The Employee Polygraph Protection Act of 1988 in the United States generally prohibits employers from using lie detector tests for pre-employment screening or during the course of employment. The use of polygraphs in national security matters aims to maintain the integrity and confidentiality of classified information. Critics such as Doug Williams and George Maschke have expressed skepticism and concerns about the reliability and validity of polygraph examinations. The National Academy of Sciences Report on Polygraph Testing provides comprehensive insights into the use and effectiveness of polygraph testing, offering valuable information for those interested in understanding its applications and limitations.\n2. Artificial Intelligence (AI) is a rapidly evolving technology with significant advancements and applications across various industries. In October 2022, DeepMind, a leading AI company owned by Alphabet Inc., released AlphaTensor, a neuro-symbolic AI that utilizes reinforcement learning to solve mathematical problems. This tool was designed to discover novel algorithms for matrix multiplication in mathematics, demonstrating its potential in advancing mathematical research and optimizing computational processes. DeepMind is also known for developing AlphaGo, an AI system that defeated a world champion Go player in 2016. Other AI systems developed by DeepMind include MuZero, which learns without being explicitly taught the rules, and the Flamingo, a visual language model that accurately describes pictures with minimal training images. Google, another major player in AI, developed Tensor Processing Units (TPUs) to enhance the performance of machine learning models. These units have been util ...

# %%
Cluster_group.to_csv('/Users/mogen/AdvancedRag/Clustered_nomic/_high_level_community_summaries.csv')

# %% [markdown]
# #combine final dataframe

# %%
import json
from collections import defaultdict

import re

# %%
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Load CSV files into dataframes
# ----> 2 Answers = pd.read_csv('/Users/mogen/AdvancedRag/Clustered_nomic/_high_community_summaries.csv')
#       3 Input = pd.read_csv('/Users/mogen/AdvancedRag/Clustered_nomic/input_high_level_community_summaries.csv')
#       5 # Assuming that the second column in 'Answers' contains the data you need to parse
#
# File ~/AdvancedRag/ARag/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/AdvancedRag/ARag/lib/python3.10/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/AdvancedRag/ARag/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/AdvancedRag/ARag/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 7 fields in line 4, saw 11

# %% [markdown]
# #### Run

# %%
df = pd.DataFrame()

df['formatted_prompt_list']=formatted_prompt_list

df.to_csv('/Users/mogen/AdvancedRag/Prompts/Prompt_communities/prompts.csv')

# %%
import torch

if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

device
# Out:
# device(type='mps')

# %%
access_token= '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'


# specify how to quantize the model
quantization_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3", quantization_config=quantization_config, device_map="mps", token=access_token)
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3")

prompt = "My favourite condiment is"

messages = [
    {"role": "user", "content": "WAS GEHT AB?"},
    ]

model_inputs = tokenizer.apply_chat_template(messages, return_tensors="pt").to("mps")

generated_ids = model.generate(model_inputs, max_new_tokens=100, do_sample=True)
tokenizer.batch_decode(generated_ids)[0]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 11
#       4 # specify how to quantize the model
#       5 quantization_config = BitsAndBytesConfig(
#       6         load_in_4bit=True,
#       7         bnb_4bit_quant_type="nf4",
#       8         bnb_4bit_compute_dtype=torch.float16,
#       9 )
# ---> 11 model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3", quantization_config=quantization_config, device_map="mps", token=access_token)
#      12 tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.3")
#      14 prompt = "My favourite condiment is"
#
# File ~/AdvancedRag/ARag/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~/AdvancedRag/ARag/lib/python3.10/site-packages/transformers/modeling_utils.py:3398, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3395     hf_quantizer = None
#    3397 if hf_quantizer is not None:
# -> 3398     hf_quantizer.validate_environment(
#    3399         torch_dtype=torch_dtype, from_tf=from_tf, from_flax=from_flax, device_map=device_map
#    3400     )
#    3401     torch_dtype = hf_quantizer.update_torch_dtype(torch_dtype)
#    3402     device_map = hf_quantizer.update_device_map(device_map)
#
# File ~/AdvancedRag/ARag/lib/python3.10/site-packages/transformers/quantizers/quantizer_bnb_4bit.py:62, in Bnb4BitHfQuantizer.validate_environment(self, *args, **kwargs)
#      60 def validate_environment(self, *args, **kwargs):
#      61     if not torch.cuda.is_available():
# ---> 62         raise RuntimeError("No GPU found. A GPU is needed for quantization.")
#      63     if not is_accelerate_available():
#      64         raise ImportError("Using `bitsandbytes` 4-bit quantization requires Accelerate: `pip install accelerate`")
#
# RuntimeError: No GPU found. A GPU is needed for quantization.

# %%
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-v0.3",trust_remote_code=True)
model_inputs = tokenizer(["A list of colors: red, blue"], return_tensors="pt").to("mps")
